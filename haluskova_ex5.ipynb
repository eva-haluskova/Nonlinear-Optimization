# %% [markdown]
# # Task 1

# %% [markdown]
# Solve the problem:
#
# ![image.png](data:image/png;base64,...)
#
# by using just the optimality conditions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Task 2

# %% [markdown]
# Consider a problem
#
# ![image.png](data:image/png;base64,...)
#
# where all the functions are twice differentiable. Show, that the **gradient of the augmented Lagrangian function** is zero in the minimizer x∗
#  of the above problem.
#
# In other words, show that ![image.png](data:image/png;base64,...)
#  is the corresponding optimal Lagrange multiplier vector.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Optimization problem

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def f_constrained(x):
    return [x[0]**2 + x[1]**2 + x[2]**2 + (1 - x[3])**2], [],[x[0]**2 + x[1]**2 - 1, x[0]**2 + x[2]**2 - 1]

# %% [markdown]
# # Task 3

# %% [markdown]
# Use the SQP method to solve the above problem. Analyze carefully the result you got! How does SQP work for this problem?

# %%
def f_constrained(x):
    return [x[0]^2 + x[1]^2 + x[2]^2 + (1 -x[3])^2],[x[0]^2 + x[1]^2 - 1,x[0]^2 + x[2]^2 - 1],[]

# %% [markdown]
# # Task 4

# %% [markdown]
# Use the augmented Lagrangian method to solve the above problem. Analyze carefully the result you got! How does the method work for this problem?

# %% [markdown]
# I'm sorry, I underestimated homework this week, and I didn't get it right.
